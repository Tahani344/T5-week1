# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df= pd.read_csv('/content/drive/MyDrive/test1/Task (1) Week 1.ipynb')

# %%
df.head()
# Out:
# Empty DataFrame
# ...

# %%
df.tail()
# Out:
# Empty DataFrame
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Columns: 221 entries, {"nbformat":4 to outputs:[]}]}
# dtypes: object(221)
# memory usage: 124.0+ bytes

# %%
df.describe()
# Out:
#        {"nbformat":4 nbformat_minor:0 metadata:{"colab":{"provenance":[]}  \
# count              0                0                                   0
# unique             0                0                                   0
# top              NaN              NaN                                 NaN
# freq             NaN              NaN                                 NaN
#
#        kernelspec:{"name":"python3" display_name:"Python 3"}  \
# count                             0                        0
# unique                            0                        0
# top                             NaN                      NaN
# freq                            NaN                      NaN
#
#        language_info:{"name":"python"}} cells:[{"cell_type":"markdown"  \
# count                                 0                              0
# unique                                0                              0
# top                                 NaN                            NaN
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
df.isna().sum()
# Out:
# {"nbformat":4                          0.0
# nbformat_minor:0                       0.0
# metadata:{"colab":{"provenance":[]}    0.0
# kernelspec:{"name":"python3"           0.0
# display_name:"Python 3"}               0.0
#                                       ...
# {"cell_type":"code".12                 0.0
# source:[].9                            0.0
# metadata:{"id":"2-U6-y6DLe_y"}         0.0
# execution_count:null.10                0.0
# outputs:[]}]}                          0.0
# Length: 221, dtype: float64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Correct any inconsistent data entries.

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#        {"nbformat":4 nbformat_minor:0 metadata:{"colab":{"provenance":[]}  \
# count              0                0                                   0
# unique             0                0                                   0
# top              NaN              NaN                                 NaN
# freq             NaN              NaN                                 NaN
#
#        kernelspec:{"name":"python3" display_name:"Python 3"}  \
# count                             0                        0
# unique                            0                        0
# top                             NaN                      NaN
# freq                            NaN                      NaN
#
#        language_info:{"name":"python"}} cells:[{"cell_type":"markdown"  \
# count                                 0                              0
# unique                                0                              0
# top                                 NaN                            NaN
# ...

# %%
df ['cells:[{"cell_type":"markdown"'].max()
# Out:
# nan

# %%
df ['cells:[{"cell_type":"markdown"'].mean()
# Out:
# nan

# %%
df ['cells:[{"cell_type":"markdown"'].sum()
# Out:
# 0

# %%
df ['cells:[{"cell_type":"markdown"'].count()
# Out:
# 0

# %%
df ['cells:[{"cell_type":"markdown"'].min()
# Out:
# nan

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
df.head()
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
pokemon.plot.scatter(x='Attack', y='Defence')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-f8a1a2da74b5> in <cell line: 1>()
# ----> 1 pokemon.plot.scatter(x='Attack', y='Defence')
#
# NameError: name 'pokemon' is not defined

# %%
df.boxplot('')

# %%
df.boxplot('cells:[{"cell_type":"markdown"')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-e14fb5f40ce7> in <cell line: 1>()
# ----> 1 df.boxplot('cells:[{"cell_type":"markdown"')
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     505 ):
#     506     plot_backend = _get_plot_backend(backend)
# --> 507     return plot_backend.boxplot_frame(
#     508         self,
#     509         column=column,
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     467     import matplotlib.pyplot as plt
#     468
# --> 469     ax = boxplot(
#     470         self,
#     471         column=column,
#
# ...

# %%
pokemon.plot.hexbin(x='Attack' ,  y='Defence' , gridsize e=15)
# Out:
#   File "<ipython-input-34-e16ff81a7b61>", line 1
#     pokemon.plot.hexbin(x='Attack' ,  y='Defence' , gridsize e=15)
#                                                     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
df.head()
# Out:
# Empty DataFrame
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Columns: 221 entries, {"nbformat":4 to outputs:[]}]}
# dtypes: object(221)
# memory usage: 124.0+ bytes

# %%
df.describe()
# Out:
#        {"nbformat":4 nbformat_minor:0 metadata:{"colab":{"provenance":[]}  \
# count              0                0                                   0
# unique             0                0                                   0
# top              NaN              NaN                                 NaN
# freq             NaN              NaN                                 NaN
#
#        kernelspec:{"name":"python3" display_name:"Python 3"}  \
# count                             0                        0
# unique                            0                        0
# top                             NaN                      NaN
# freq                            NaN                      NaN
#
#        language_info:{"name":"python"}} cells:[{"cell_type":"markdown"  \
# count                                 0                              0
# unique                                0                              0
# top                                 NaN                            NaN
# ...

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
pokemon.plot.scatter(x='Attack', y='Defence')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-f8a1a2da74b5> in <cell line: 1>()
# ----> 1 pokemon.plot.scatter(x='Attack', y='Defence')
#
# NameError: name 'pokemon' is not defined

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>
